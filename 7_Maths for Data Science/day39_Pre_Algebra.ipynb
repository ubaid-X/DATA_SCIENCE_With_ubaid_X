# %% [markdown]
# __Author name__: UBAIDULLAH
#
# [GitHub Profile](https://github.com/ubaid-X/)
#
# [LinkedIn Profile](https://https://www.linkedin.com/in/ubaid-ullah-634563373/)
#
# [Kaggle Profile](https://www.kaggle.com/ubaidullah01)
#
# __Email__: `ai.bussiness.student0@gmail.com`

# %% [markdown]
# ---
# > # __Chapter 2: The World of Fractions and Decimals__

# %% [markdown]
# ---
# > ### __1.Fractions__
#
# fraction is a combination of two integers in `p/q` the `p` is nominator and `q` is denominator.
#
# - ###  __Simplifying Fractions__
#
# To simplify a fraction, you divide the top and bottom by the highest number that divides into both exactly.
#
# __Example__: Simplify 8/12. Both 8 and 12 can be divided by 4, so (8÷4)/(12÷4) = 2/3.
#
# ---
#
# - ### __Common Denominator in algebra__
#
# A common denominator is a shared multiple of the denominators of two or more fractions. It’s used to add or subtract fractions.
#
# __Example__: To add 1/4 and 3/5, find a common denominator, which is 20, so 1/4 = 5/20 and 3/5 = 12/20.
#
# ---
#
# - ### __Adding and Subtracting Fractions in algebra__
#
# Fractions must have a common denominator to be added or subtracted. Then you add or subtract the numerators and keep the denominator the same.
#
# __Example__: 5/20 + 12/20 = 17/20.
#
# ---
#
# - ### __Multiplying and Dividing Fractions in algebra__
#
# To multiply fractions, multiply the numerators and denominators separately. To divide, flip the second fraction and multiply.
#
# __Example__: 2/3 × 3/4 = 6/12 simplifies to 1/2. For division, 2/3 ÷ 3/4 = 2/3 × 4/3 = 8/9.
#
# ---
#
# - ### __Mixed Numbers and Improper Fractions in algebra__
#
# A mixed number combines a whole number and a fraction, while an improper fraction has a numerator larger than its denominator.
#
# __Example__: 3½ is a mixed number. To convert it to an improper fraction: 3 × 2 + 1 = 7, so 3½ becomes 7/2.
#
# ---
#
# > ### __2.Decimals__
#
# - ## __Converting Fractions to Decimals__
#
# To convert a fraction to a decimal, divide the numerator by the denominator.
#
# __Example__: 3/4 becomes 0.75 because 3 ÷ 4 = 0.75.
#
# ---
#
# - ## __Adding, Subtracting, Multiplying, and Dividing Decimals__
#
# When adding or subtracting decimals, align the decimal points. For multiplication, multiply as with whole numbers, and count the total number of decimal places in both factors for the result. Division is done like whole numbers, but you may need to move the decimal point.
#
# __Example__: 0.5 + 0.25 = 0.75, and 0.5 × 0.2 = 0.10. For division, 0.75 ÷ 0.5 = 1.5.
#
# ---
#
# - ## __Rounding Decimals__
#
# Rounding decimals involves shortening a decimal to a certain number of decimal places, based on the next digit.
#
# __Example__: Round 3.14159 to two decimal places: Since the third decimal is 1, round down to 3.14.
#
# ---
#
# - ## __Decimal Places and Significant Figures__
#
# Decimal places count the numbers after the decimal point. Significant figures include all the meaningful digits in a number, not just after the decimal.
#
# __Example__: In 123.45, there are two decimal places and five significant figures.
#
# ---
#
# > # Assignment
# ---
# 1. Simplify the fraction 15/35.
#
# Ans. 15/35 `-->` 3/7
#
# ---
#
# 2. Find the common denominator for 1/4 and 5/6.
#
# Ans. The common denominator is `24`
#
# ---
#
# 3. Calculate 2/3 + 4/5.
#
# Ans. `step 1`  2/3 + 4/5
#
# .
#      `step 2`  10 + 12 / 15
#
# .
#      `step 3`  `22/15`
#
# ---
#
# 4. Multiply 7/8 by 1/2.
#
# Ans. `step 1` 7/8 x 1/2
#
# .
#      `step 2` `7/16`
#
# ---
#
# 5. Convert the mixed number 3 1/2 to an improper fraction.
#
# Ans. `step 1` 3 1/2
#
# .
#      `step 2` `7/2`  because 2 x 3 + 1 = 7 and the dinominator will be on same place
#
# ---
#
# 6. Express 0.75 as a fraction.
#
# Ans. `step 1` 75/100 = 0.75
#
# .
#      `step 2` `75/25 = 3` and `100/25 = 4` because dividing both by their GCD
#
# .
#      `step3`  Final Answer: `3/4`
#
# ---
#
# 7. Subtract 0.9 from 2.5.
#
# Ans. 2.5 - 0.9 = `1.6`
#
# ---
#
# 8. Multiply 0.8 by 0.05.
#
# Ans. 0.8 x 0.05 = `0.04`
#
# ---
#
# 9. Round 3.14159 to the nearest hundredth.
#
# Ans. `3.14`
#
# ---
#
# 10. Identify the decimal place and significant figure for 0.042.
#
# Ans. the Decimal place in `0.042` is `3`, While significant figure is `4`
#
# ---
#
# 11. Convert the decimal 0.625 to a fraction.
#
# Ans. `step 1`  625/1000 = 0.625
#
# .
#      `step 2` 625/125 = 5 and 1000/125 = 8 , because `125` GCD for 625 and 1000
#
# .
#      `step 3` 0.625 = `5/8`
#
# ---
#
# 12. Add 0.2 to 1/3 after converting them to a common format.
#
# Ans. `step 1` 0.2 = 2/10 = 1/5 , converting to fraction
#
# .
#      `step 2` 1/5 + 1/3
#
# .
#      `sep 3`  3 + 5 / 15
#
# .
#      `step 4` Answer: `8/15`
#
# ---
#
# 13. Divide 5 by 0.5 and express the answer as a decimal.
#
# Ans. 5/0.5 = `10.0`
#
# ---
#
# 14. Write 1/8 as a decimal without using a calculator.
#
# Ans. `0.125`
#
# ---
#
# 15. Round the number 7.456 to the nearest tenth.
#
# Ans. `7.5`
#
# ---

# %% [markdown]
# ---
# > # __Chapter 3: The Power of Ratios and Proportions__

# %% [markdown]
# > ### __1. Ratios__
#
# ---
#
# - ## __Writing and Simplifying Ratios__
#
# Ratios compare two quantities by division. When writing ratios, it’s important to keep the order consistent and simplify them as much as possible.
#
# __Example__: The ratio of 8 oranges to 4 apples can be written as 8:4 and simplified to 2:1.
#
# ---
#
# - ## __Equivalent Ratios__
#
# Equivalent ratios have the same value when simplified, even though they may look different.
#
# __Example__: The ratios 2:1 and 4:2 are equivalent because when both are simplified, they result in the same ratio of 2:1.
#
# ---
#
# > ### __2. Proportions__
# ---
# - __Setting up Proportions__
#
# A proportion is an equation that states two ratios are equal. To set up a proportion, you need to have four related quantities.
#
# __Example__: If 2 oranges cost $1, how much do 6 oranges cost? The proportion would be 2/1 = 6/x, where x is the cost of 6 oranges.
#
# ---
#
# - __Solving Proportions__
#
# To solve proportions, find the value of the variable that makes the two ratios equal.
#
# __Example:__ To solve 2/1 = 6/x, cross-multiply to get 2x = 6, then divide both sides by 2 to find x = 3. So, 6 oranges cost $3.
#
# ---
#
# - __Direct Variation__
#
# Direct variation occurs when two quantities increase or decrease together at the same rate.
#
# __Example__: If y varies directly with x and y = 2 when x = 1, then the equation of direct variation is y = 2x.
#
# ---
#
# - __Inverse Variation__
#
# Inverse variation happens when one quantity increases while the other decreases. Their product is a constant.
#
# __Example__: If y varies inversely with x and y = 1 when x = 2, then the equation of inverse variation is xy = 2.
#
# ---

# %% [markdown]
# > ### __Assignment__
#
# 1. Write the ratio of 8 to 12 in simplest form.
#
# Ans. 8:12 => `2:3`   , Both divided by `4`
#
# ---
#
# 2. Are the ratios 3/4 and 9/12 equivalent?
#
# Ans. 9:12 --> 3:4 , Divided by 3
#     `yes it is equivalent`
#
# ---
#
# 3. Set up a proportion to find the unknown number x if x/3 = 12/4.
#
# Ans. `step 1`  12/4 = x/3
#
# .
#      `step 2`  4x = 36
#
# .
#      `step 3`  4x/4 = 36/4    , both divide by `4`
#
# .
#      `step 4`  `x = 9`
#
# ---
#
# 4. If y varies directly with x and y = 10 when x = 2, find y when x = 5.
#
# Ans. `y = kx` --> Y = 10 X 5 --> `Y = 50`
#
# ---
#
# 5. If y varies inversely with x and y = 8 when x = 4, what is y when x = 2?
#
# Ans. `y = k/x` --> y = 8/2 --->  `y = 4`
#
# ---
#
# 6. Express the ratio of 30 minutes to 1.5 hours in simplest form.
#
# Ans. `step 1`  converting hourse to minute 1.5 x 60 = `90 minutes`
#
# .
#      `step 2` 30:90
#
# .
#      `step 3` 1:3  divide by GCD: `30`
#
# ---
#
# 7. Determine if the following ratios form a proportion: 6/8 and 9/12.
#
# Ans. `step 1`  6:8 and 9:12
#
# .
#      `step 2`  3:4 and 3:4    => 1st fraction divided by 2 and 2nd divided by 3
#
# .
#      `yes it is form a proportion`
#
# ---
#
# 8. Convert the ratio 5:6 into a fraction.
#
# Ans. `5/6`
#
# ---
#
# 9. If a bag contains red and blue marbles in a ratio of 2:3, how many red marbles are there if there are 18 blue marbles?
#
# Ans.  red = 2, blue = 3, if blue = 18 than find red = ?
#
# .
#      `step 1` 2/3 = x/18
#
# .
#      `step 2` 3x = 36
#
# .
#      `step 3` 3x/3 = 36/3
# .
#      `step 4` __Answer__: `x = 12`
#
# ---
#
# 10. The ratio of the length to the width of a rectangle is 3:2. If the width is 10 inches, find the length.
#
# Ans. length = 3, width = 2 , if width = 10 inches so find length = ?
#
# .
#      `step 1`  3/2 = x/10
#
# .
#      `step 2`  2x = 30
#
# .
#      `step 3`  2x/2 = 30/2  , both divided by 2
#
# .
#      `step 4`  __Answer__: `x = 15`
#
# ---

# %% [markdown]
# ---
# > # __Chapter 4: Mastering the Art of Percentages in Algebra__

# %% [markdown]
# > ### __Understanding Percentages__
#
# - ## __Converting Fractions and Decimals to Percentages__
#
# Percentages are a way of expressing numbers as a fraction of 100. To convert a fraction or a decimal to a percentage, multiply by 100 and add the percent symbol (%) at the end.
#
# __Example__: Convert 0.75 to a percentage: 0.75 × 100 = 75%.
#
# __Example__: Convert 3/4 to a percentage: First convert 3/4 to a decimal which is 0.75, then multiply by 100 to get 75%.
#
# - ## __Converting Percentages to Fractions and Decimals__
#
# To convert a percentage to a decimal, divide by 100. To convert a percentage to a fraction, write the percentage over 100 and simplify if possible.
#
# __Example__: Convert 50% to a decimal: 50 ÷ 100 = 0.5.
#
# __Example__: Convert 50% to a fraction: 50% = 50/100 = 1/2.
#
# - ## __Finding Percentages of Numbers__
# To find a percentage of a number, convert the percentage to a decimal and multiply by the number.
#
# __Example__: Find 20% of 50: Convert 20% to a decimal (0.20) and multiply by 50 (0.20 × 50 = 10).
#
# - ## __Percentage Increase and Decrease__
#
# Percentage increase or decrease measures how much a number has gone up or down in percentage terms.
#
# __Example__: If a shirt was $50 and now is $65, the percentage increase is calculated as: [(65 – 50) ÷ 50] × 100 = 30% increase.
#
# __Example__: If a stock price drops from $30 to $25, the percentage decrease is: [(30 – 25) ÷ 30] × 100 = approximately 16.67% decrease.
#
# ---

# %% [markdown]
# > # __Assignment__
#
# 1. Convert the fraction 3/5 to a percentage.
#
# Ans. 3/5 = 0.6 => 0.6 x 100 = `60`
#
# ---
#
# 2. Change 40% to a decimal.
#
# Ans. 40/100 = `0.4`
#
# ---
#
# 3. What is 25% of 200?
#
# Ans. (200/100) x 25 = `50`
#
# ---
#
# 4. If a dress costs $70 after a 30% discount, what was the original price?
#
# Ans.  original price  `x = ?`  and i pay price = 100% - 30% => `70%` , to fraction: 70/100 = `0.7` ,
#       70% of X = $70
#     so,
#     `step 1`  0.7 x X = 70
#
# .
#     `step 2` X = 70/0.7
#
# .
#     `step 3` __Answer:__   `X = $100`
#
# ---
#
# 5. A population of 50,000 increases by 5% per year. What is the population after one year?
#
# Ans. `step 1`  5% = 5/100 => `0.05`
#
# .
#      `step 2`  50000 x 0.05 => `2500`
#
# .
#      `step 3` after one year populatio is 50000 + 2500 = `52500`
#
# ---
#
# 6. Calculate the percentage decrease if a product’s price drops from $200 to $150.
#
# Ans. `step 1` 200 - 150 = `50`
#
# .
#      `step 2` (50/200) x 100 = 25%
#
# .
#      `so the product's price is decreased by 25%`
#
# ---
#
# 7. Find 150% of 60.
#
# Ans. `step 1` 150/100 = `1.50`
#
# .
#       `step 2` 1.50 x 60 = `90`
#
# ---
#
# 8. What percentage of a day is 6 hours?
#
# Ans.(part/whole) x 100
#
# .
#     `step 1` (6/24) x 100
#
# .
#     `step 2` 0.25 x 100
#
# .
#     `step 3` `25%`
#
# --
#
# 9. If you save $20 on a $50 item, what percent discount is that?
#
# Ans. `step 1` (20/50) x 100
#
# .
#      `step 2` 0.4 x 100 = `40%`
#
# ---
#
# 10. A score of 80% is needed to pass a test. If the test has 50 questions, how many questions must you answer correctly?
#
# Ans. `step 1` (80 x 50) / 100
#
# .
#      `step 2` 4000 /100 = `40`
#
# ---

# %% [markdown]
# ---
#
# > ### 📊 Percentage Formulas for Data Scientists
#
# ---
#
# ## 1. Basic Percentage Formula
#
# Formula:
#
# (Part / Whole) × 100 = Percentage
#
# Example:
#
# In a dataset of 10,000 entries, 2,000 have missing values.
# Missing Percentage = (2000 / 10000) × 100 = 20%
#
# ---
#
# ## 2. Percentage Change
#
# Formula:
#
# ((New Value - Old Value) / Old Value) × 100 = Percentage Change
#
# Example:
#
# User traffic increased from 5,000 to 6,000:
# ((6000 - 5000) / 5000) × 100 = 20% increase
#
# ---
#
# ## 3. Percentage of a Total
#
# Formula:
#
# (Percentage × Total) / 100 = Value
#
# Example:
#
# Sample 15% of a 20,000-row dataset:
# (15 × 20000) / 100 = 3000 rows
#
# ---
#
# 4. Discount or Price Reduction Percentage
#
# Formula:
#
# (Discount Amount / Original Price) × 100 = Discount %
#
# Example:
#
# A product was 250, now200 → Discount = $50
# (50 / 250) × 100 = 20% discount
#
# ---
#
# 5. Percentage Error (Used in Regression)
#
# Formula:
#
# ((Actual - Predicted) / Actual) × 100 = % Error
#
# Example:
#
# Actual sales = 500, Predicted = 450
# ((500 - 450) / 500) × 100 = 10% error
#
# ---
#
# 6. Class Distribution Percentage
#
# Formula:
#
# (Class Count / Total Count) × 100
#
# Example:
#
# 800 positive and 200 negative samples in 1000 total:
# (800 / 1000) × 100 = 80% positive
#
# ---
