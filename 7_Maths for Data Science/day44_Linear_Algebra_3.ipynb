# %% [markdown]
# ---
# __About Section:__
#
# - __Author name:__ UBAIDULLAH
#
# - __Email:__ [ai.bussiness.student0@gmail.com](mailto:ai.bussiness.student0@gmail.com)
#
# - __GitHub:__ [github.com/ubaid-X/](https://github.com/ubaid-X/)
#
# - __LinkedIn Profile:__ [linkedin.com/in/ubaid-ullah-634563373/](https://www.linkedin.com/in/ubaid-ullah-634563373/)
#
# - __Kaggle:__ [kaggle.com/ubaidullah01](https://www.kaggle.com/ubaidullah01)
#
# ---

# %% [markdown]
# ---
#
# > # __Linear Algebra: Vectors, Products & Intercepts__
#
# ### 0. __📝 Summary__
# This notebook covers key vector-related topics in linear algebra,
# including vector operations, vector space fundamentals,
# and geometry-based concepts like intercepts and products.
# Each section includes definitions, examples, visuals, and tips to build strong intuition.
#
# ---

# %% [markdown]
# > ### __1. Vector Addition__
#
# __Definition:__
# Vector addition is the process of combining two vectors to form a resultant vector.
#
# __Explanation:__
#
# If *v = (v₁, v₂)* and *u = (u₁, u₂)*, then:
#
# ```math
# v⃗ + u⃗ = (v_1 + u_1,\ v_2 + u_2)
# ```
#
# __Example:__
#
# ```math
# v⃗ = (3, 2),\quad u⃗ = (1, 4)
# ```
#
# ```math
# v⃗ + u⃗ = (3+1,\ 2+4) = (4, 6)
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

v = np.array([3, 2])
u = np.array([1, 4])
result = v + u

plt.quiver(0, 0, *v, color='blue', angles='xy', scale_units='xy', scale=1, label='v')
plt.quiver(*v, *u, color='green', angles='xy', scale_units='xy', scale=1, label='u (from v)')
plt.quiver(0, 0, *result, color='red', angles='xy', scale_units='xy', scale=1, label='v + u')

plt.xlim(0, 6)
plt.ylim(0, 7)
plt.grid()
plt.legend()
plt.title('Vector Addition')
plt.show()

# %% [markdown]
# __💡 Tips and Tricks__
# - Think of it as moving along v, then along u.
# - Order doesn’t matter: *v + u = u + v*
#
# ---

# %% [markdown]
# > ### __2. Vector Span & Linear Dependence__
#
# __Definition:__
# - *Span*: The set of all linear combinations of given vectors.
# - *Linearly Dependent*: One vector can be written as a combination of others.
# - *Linearly Independent*: No vector in the set can be written using the others.
#
# __Explanation:__
# Vectors *v₁, v₂, ..., vₙ* are linearly dependent if:
#
# ```math
# c_1 v⃗_1 + c_2 v⃗_2 + \dots + c_n v⃗_n = 0⃗
# ```
#
# ...has a non-zero solution (not all cᵢ = 0).
#
# __Example:__
#
# ```math
# v⃗_1 = (2, 4),\quad v⃗_2 = (1, 2)
# ```
# Here, *v₁ = 2 × v₂* → They are *linearly dependent*.
#
# ---
#
# 💡 Tips
# - Use determinant or rank tests in higher dimensions.
# - Independent vectors create a *basis*.
#
# ---

# %% [markdown]
# > # __3. Vector Space__
#
# __Definition:__
# A *vector space* is a collection of vectors that can be added and scaled and still remain in the space.
#
# __Requirements (Properties):__
# 1. Closed under addition
# 2. Closed under scalar multiplication
# 3. Contains a zero vector
# 4. Obeys vector space axioms (associativity, distributivity, etc.)
#
# __Example:__
#
# Set of all 2D vectors *(x, y)* over real numbers *ℝ²* is a vector space.
#
# ---
#
# __💡 Tips and Tricks:__
# - Common spaces: *ℝ²*, *ℝ³*, matrix space, function space
# - Vectors must remain inside the set under all operations
#
# ---

# %% [markdown]
# > # __4. X and Y Intercepts in Linear Algebra__
#
# __Definition:__
# - *X-intercept*: Point where line crosses x-axis (*y = 0*)
# - *Y-intercept*: Point where line crosses y-axis (*x = 0*)
#
# __Explanation:__
#
# Given a linear equation:
#
# ```math
# y = mx + b
# ```
#
# - *Y-intercept* is *b*
# - To find X-intercept, set *y = 0*, solve for *x*
#
# __Example:__
#
# ```math
# y = 2x - 4
# ```
# - Y-intercept: (0, -4)
# - X-intercept:
#   Set y = 0
#   ```math
#   0 = 2x - 4 \Rightarrow x = 2
#   → X-intercept = (2, 0)
#   ```
#
# ---
#
# __💡 Tips and Tricks__
# - Always set the *other variable to zero* to find an intercept.
# - Intercepts help sketch linear graphs quickly.
#
# ---

# %% [markdown]
# > # __5. Dot Product of Vectors__
#
# __Definition:__
# The *dot product* of two vectors returns a *scalar*, representing projection and angle relation.
#
# __Formula:__
#
# ```math
# a⃗ \cdot b⃗ = a_x b_x + a_y b_y
# ```
#
# Or __using angle:__
#
# ```math
# a⃗ \cdot b⃗ = |a⃗| |b⃗| \cos(\theta)
# ```
#
# __Example 1:__
# ```math
# a⃗ = (3, 4),\quad b⃗ = (2, -1)
# ```
#
# ```math
# a⃗ \cdot b⃗ = 3×2 + 4×(–1) = 6 – 4 = 2
# ```
#
# ---
#
# __Example 2:__
# Let
# *A = (2, 3, 4)*
# *B = (1, 0, -2)*
# We want to find *A · B*
#
# ---
#
# ✅ *Step-by-Step Explanation*
#
# *Step 1: Understand the Dot Product*
#
# The *dot product* (also called scalar product) is a way to multiply two vectors that gives a *single number (a scalar)*.
#
# Formula:
#
# ```math
# A⃗ \cdot B⃗ = A_x B_x + A_y B_y + A_z B_z
# ```
#
# It measures *how much one vector goes in the direction of another*.
#
# ---
#
# *Step 2: Plug in the Components*
#
# We are given:
#
# - A = (2, 3, 4)
# - B = (1, 0, -2)
#
# Now apply the formula:
#
# ```math
# A \cdot B = (2 × 1) + (3 × 0) + (4 × -2)
# ```
#
# ---
#
# *Step 3: Multiply Each Pair*
#
# ```math
# = 2 + 0 - 8
# ```
#
# ---
#
# *Step 4: Add the Results*
#
# ```math
# = -6
# ```
#
# ---
#
# ✅ *Final Answer:*
# ```math
# A⃗ \cdot B⃗ = -6
# ```
#
# ---
#
# 🧠 *Tips:*
#
# - If *dot product = 0*, vectors are *perpendicular*
# - Positive result → same direction
# - Negative result → opposite direction
# - Used in projections, angles, machine learning
#
# ---
#
# > # __6. Cross Product of Two Vectors__
#
# __Definition:__
# The *cross product* of two vectors results in a new vector *perpendicular* to both (only in 3D).
#
# __Formula:__
#
# __If:__
#
# ```math
# a⃗ = (a_1, a_2, a_3),\quad b⃗ = (b_1, b_2, b_3)
# ```
#
# __Then:__
#
# a \times b =
# \begin{vmatrix}
# î & ĵ & k̂ \\
# a_1 & a_2 & a_3 \\
# b_1 & b_2 & b_3 \\
# \end{vmatrix}
#
# ---
#
# __Example 1:__
#
# Let
# *A = (2, 3, 4)*
# *B = (1, 0, -2)*
#
# We want to find *A × B*
#
# ---
#
# ✅ *Step-by-Step Explanation*
#
# *Step 1: Understand the Cross Product*
# The *cross product* of two 3D vectors gives you another vector that is:
# - *Perpendicular* to both original vectors
# - Calculated using a *determinant*
# - Has direction (not just magnitude)
#
# ---
#
# *Step 2: Set up the Determinant*
#
# We use the determinant of a 3×3 matrix:
#
# ```
# |  i   j   k  |
# |  2   3   4  |
# |  1   0  -2  |
# ```
#
# Where:
# - `i`, `j`, `k` are the unit vectors for x, y, z directions
# - The second row is vector A (2, 3, 4)
# - The third row is vector B (1, 0, -2)
#
# ---
#
# *Step 3: Expand the Determinant*
#
# Now, apply the determinant rule:
#
# ```
# A × B = î (3×-2 − 4×0) − ĵ (2×-2 − 4×1) + k̂ (2×0 − 3×1)
# ```
#
# Now do the math:
#
# - î component: (3×-2 − 4×0) = -6
# - ĵ component: (2×-2 − 4×1) = -4 − 4 = -8 → minus sign makes it +8
# - k̂ component: (2×0 − 3×1) = -3
#
# ---
#
# *Step 4: Write the Final Vector*
#
# ```
# A × B = -6 î + 8 ĵ − 3 k̂
# ```
#
# Or as a vector:
#
# ```
# A × B = (-6, 8, -3)
# ```
#
# ---
#
# 🧠 *Tips:*
#
# - Use the determinant method when working in 3D.
# - Always follow the *sign rules* (j term always gets a negative).
# - The result vector is *perpendicular* to both input vectors.
# - Cross product only works in 3D.
# - The result is *orthogonal* to both vectors.
# - Used in physics (torque, angular momentum).
#
# ---
#
# __Conclusion:__
#
# __You now understand:__
#
# - Vector operations (add, scale, span)
#
# - Products (dot & cross)
#
# - Intercepts in linear systems
#
# - Vector space theory
#
# These form the basis of advanced applications like projections, transformations, and 3D geometry in linear algebra.
#
# ---
