# %% [markdown]
# ---
# __About Section:__
#
# - __Author name:__ UBAIDULLAH
#
# - __Email:__ [ai.bussiness.student0@gmail.com](mailto:ai.bussiness.student0@gmail.com)
#
# - __GitHub:__ [github.com/ubaid-X/](https://github.com/ubaid-X/)
#
# - __LinkedIn Profile:__ [linkedin.com/in/ubaid-ullah-634563373/](https://www.linkedin.com/in/ubaid-ullah-634563373/)
#
# - __Kaggle:__ [kaggle.com/ubaidullah01](https://www.kaggle.com/ubaidullah01)
#
# ---

# %% [markdown]
# # __Statistics__
# Statistics is the science of collecting, aalyzing, interpreting,presenting and Organized the data.It's like the GPS in the journey of decision-making ,guiding us through the maze of information with clarity and precision.
#
# ## __Analyzing the Data__
#
# ### __1. Descriptive Statistics:__
# - Samarizing the data
# - Describe the data
# - Laithy grities
# - Explore the data (EDA)
# - Features etc
# ```
#                     Comparison
#                          |
#                          |
#                          |
#    Distribution ------- Data -------- Composition
#                          |
#                          |
#                          |
#                       Relation
# ```
# > # __Charts Guide by Andrew nabela according to EDA pillars__
#
# ![nabela](./math_pics/Chart_Guide.png)
#
# ---
#
# ### Composition / Distribution
# - Population vs Sample
# - Central Tendency
#   - Mean
#   - Median
#   - Mode
# - Measure of Variance/Disperssion/Spread
# - Outliers
# - Data Visualization tools and plots
#   - Frequency plots
#   - Bar Charts
#     - Histogram ----> Distribution
#     - Bar Plot --> Outlier
#   -Bivariate plots
#    - Scatter plot
#    - Line Chart
#
# > __The above all comes in `Composition / Distribution`
#
# ## __The Comparison and Corelation__
# - We Use Different types of Statistical Test
#
#    - T-test
#    - ANOVA
#    - Chi-Square Test
#    - Correlation
#       - Pearson
#       - Spearman
#       - Kendall
#
# ---
#
# ![test1](./math_pics/test1.png)
# ![test2](./math_pics/test2.png)
#
# ---
#
# ![test3](./math_pics/test3.png)
# ![test4](./math_pics/test4.png)
# ![test5](./math_pics/test5.png)
#
# ---
#
# # __The steps is Assumptions(Shaaraith) for the Statistical(parametric) Test like Normality test etc__
#
# ![test6](./math_pics/test6.png)
# ![test7](./math_pics/test7.png)
# ![test8](./math_pics/test8.png)
# ![test9](./math_pics/test9.png)
# ![test10](./math_pics/test10.png)
# ![test11](./math_pics/test11.png)
# ![test12](./math_pics/test12.png)
# ![test13](./math_pics/test13.png)
# ![test14](./math_pics/test14.png)
# ![test15](./math_pics/test15.png)
# ![test16](./math_pics/test16.png)
# ![test17](./math_pics/test17.png)
# ![test18](./math_pics/test18.png)
# ![test19](./math_pics/test19.png)
# ![test20](./math_pics/test20.png)
# ![test21](./math_pics/test21.png)
# ![test22](./math_pics/test22.png)
# ![test23](./math_pics/test23.png)
#
#
# ---
#
# ### __Steps to do EDA__
#
# ```
#                     Comparison
#                          |
#                          |
#                          |
#    Distribution ------- Data -------- Composition
#                          |
#                          |
#                          |
#                       Relation
# ````
# 1. First do Composition and than Distribution
# 2. Then do Comparison and Relation
#
# > __After completing the Descriptive Analysis than come the inferencial Analysis which are about Predictions__
# ---
